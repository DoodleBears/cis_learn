t.rcParams['savefig.dpi'] = 300 #图片像素
plt.rcParams['figure.dpi'] = 300 #分辨率
# 默认的像素：[6.0,4.0]，分辨率为100，图片尺寸为 600&400
# 指定dpi=200，图片尺寸为 1200*800
# 指定dpi=300，图片尺寸为 1800*1200
# 设置figsize可以在不改变分辨率情况下改变比例

# %%
range_x_left, range_y_left = 0, 0.55
range_x_right, range_y_right = 100,0.74
plt.title("Accuracy of FM and FFM")
plt.xlabel('ratio of part-of-train data and all-train data')
plt.ylabel('acc') 
plt.xlim([range_x_left, range_x_right]) 
plt.ylim([range_y_left, range_y_right]) 
plt.plot(ffm_acc_dict_list.keys(),ffm_acc_dict_list.values() ,'b*', label='FFM')
plt.plot(ffm_acc_dict_list.keys(),ffm_acc_dict_list.values() ,'b.-')
plt.plot(fm_acc_dict_list.keys(),fm_acc_dict_list.values() ,'r*', label='FM')
plt.plot(fm_acc_dict_list.keys(),fm_acc_dict_list.values() ,'r.-')
x_major_locator=MultipleLocator(10)
#把x轴的刻度间隔设置为1，并存在变量里
# y_major_locator=MultipleLocator(10)
#把y轴的刻度间隔设置为10，并存在变量里
ax=plt.gca()
#ax为两条坐标轴的实例
ax.xaxis.set_major_locator(x_major_locator)
#把x轴的主刻度设置为1的倍数
# ax.yaxis.set_major_locator(y_major_locator)
#把y轴的主刻度设置为10的倍数
plt.legend()
plt.savefig('Accuracy_of_FM_and_FFM.png', dpi=300) #指定分辨率保存
plt.show()

# %%
range_x_left, range_y_left = 0, 0.625
range_x_right, range_y_right = 100,0.73
plt.title("Accuracy of FFM")
plt.xlabel('ratio of part-of-train data and all-train data')
plt.ylabel('acc') 
plt.xlim([range_x_left, range_x_right]) 
plt.ylim([range_y_left, range_y_right]) 
plt.plot(ffm_acc_dict_list.keys(),ffm_acc_dict_list.values() ,'b*', label='FFM')
plt.plot(ffm_acc_dict_list.keys(),ffm_acc_dict_list.values() ,'b.-')
x_major_locator=MultipleLocator(10)
#把x轴的刻度间隔设置为1，并存在变量里
# y_major_locator=MultipleLocator(10)
#把y轴的刻度间隔设置为10，并存在变量里
ax=plt.gca()
#ax为两条坐标轴的实例
ax.xaxis.set_major_locator(x_major_locator)
#把x轴的主刻度设置为1的倍数
# ax.yaxis.set_major_locator(y_major_locator)
#把y轴的主刻度设置为10的倍数
plt.legend()
plt.savefig('Accuracy_of_FFM.png', dpi=300) #指定分辨率保存
plt.show()

# %%
range_x_left, range_y_left = 0, 0.568
range_x_right, range_y_right = 100,0.572
plt.title("Accuracy of FM")
plt.xlabel('ratio of part-of-train data and all-train data')
plt.ylabel('acc') 
plt.xlim([range_x_left, range_x_right]) 
plt.ylim([range_y_left, range_y_right]) 
plt.plot(fm_acc_dict_list.keys(),fm_acc_dict_list.values() ,'r*', label='FM')
plt.plot(fm_acc_dict_list.keys(),fm_acc_dict_list.values() ,'r.-')
x_major_locator=MultipleLocator(10)
#把x轴的刻度间隔设置为1，并存在变量里
# y_major_locator=MultipleLocator(10)
#把y轴的刻度间隔设置为10，并存在变量里
ax=plt.gca()
#ax为两条坐标轴的实例
ax.xaxis.set_major_locator(x_major_locator)
#把x轴的主刻度设置为1的倍数
# ax.yaxis.set_major_locator(y_major_locator)
#把y轴的主刻度设置为10的倍数
plt.legend()
plt.savefig('Accuracy_of_FM.png', dpi=300) #指定分辨率保存
plt.show()

# %%
range_x_left, range_y_left = 0, 0.54
range_x_right, range_y_right = 100,0.69
plt.title("Loss of FM and FFM")
plt.xlabel('ratio of part-of-train data and all-train data')
plt.ylabel('acc') 
plt.xlim([range_x_left, range_x_right]) 
plt.ylim([range_y_left, range_y_right]) 
plt.plot(ffm_loss_dict_list.keys(),ffm_loss_dict_list.values() ,'b*', label='FFM')
plt.plot(ffm_loss_dict_list.keys(),ffm_loss_dict_list.values() ,'b')
plt.plot(fm_loss_dict_list.keys(),fm_loss_dict_list.values() ,'r*', label='FM')
plt.plot(fm_loss_dict_list.keys(),fm_loss_dict_list.values() ,'r')
x_major_locator=MultipleLocator(10)
#把x轴的刻度间隔设置为1，并存在变量里
# y_major_locator=MultipleLocator(10)
#把y轴的刻度间隔设置为10，并存在变量里
ax=plt.gca()
#ax为两条坐标轴的实例
ax.xaxis.set_major_locator(x_major_locator)
#把x轴的主刻度设置为1的倍数
# ax.yaxis.set_major_locator(y_major_locator)
#把y轴的主刻度设置为10的倍数
plt.legend()
plt.savefig('Loss_of_FM_and_FFM.png', dpi=300) #指定分辨率保存
plt.show()

# %%
range_x_left, range_y_left = 0, 0.54
range_x_right, range_y_right = 100,0.66
plt.title("Loss of FFM")
plt.xlabel('ratio of part-of-train data and all-train data')
plt.ylabel('acc') 
plt.xlim([range_x_left, range_x_right]) 
plt.ylim([range_y_left, range_y_right]) 
plt.plot(ffm_loss_dict_list.keys(),ffm_loss_dict_list.values() ,'b*', label='FFM')
plt.plot(ffm_loss_dict_list.keys(),ffm_loss_dict_list.values() ,'b')
x_major_locator=MultipleLocator(10)
#把x轴的刻度间隔设置为1，并存在变量里
# y_major_locator=MultipleLocator(10)
#把y轴的刻度间隔设置为10，并存在变量里
ax=plt.gca()
#ax为两条坐标轴的实例
ax.xaxis.set_major_locator(x_major_locator)
#把x轴的主刻度设置为1的倍数
# ax.yaxis.set_major_locator(y_major_locator)
#把y轴的主刻度设置为10的倍数
plt.legend()
plt.savefig('Loss_of_FFM.png', dpi=300) #指定分辨率保存
plt.show()

# %%
range_x_left, range_y_left = 0, 0.676
range_x_right, range_y_right = 100,0.679
plt.title("Loss of FM")
plt.xlabel('ratio of part-of-train data and all-train data')
plt.ylabel('acc') 
plt.xlim([range_x_left, range_x_right]) 
plt.ylim([range_y_left, range_y_right]) 
plt.plot(fm_loss_dict_list.keys(),fm_loss_dict_list.values() ,'r*', label='FM')
plt.plot(fm_loss_dict_list.keys(),fm_loss_dict_list.values() ,'r')
x_major_locator=MultipleLocator(10)
#把x轴的刻度间隔设置为1，并存在变量里
# y_major_locator=MultipleLocator(10)
#把y轴的刻度间隔设置为10，并存在变量里
ax=plt.gca()
#ax为两条坐标轴的实例
ax.xaxis.set_major_locator(x_major_locator)
#把x轴的主刻度设置为1的倍数
# ax.yaxis.set_major_locator(y_major_locator)
#把y轴的主刻度设置为10的倍数
plt.legend()
plt.savefig('Loss_of_FM.png', dpi=300) #指定分辨率保存
plt.show()
