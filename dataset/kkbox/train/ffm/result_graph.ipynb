                  10:0.594363, 20:0.576963, 30:0.568939, 40:0.562357, 50:0.557465, 60:0.553988, 70:0.551922, 80:0.549487, 90:0.548061,
                  100:0.546194 }

# %%
fm_acc_dict_list = {1:0.625662, 2:0.633120, 3:0.637661, 4:0.642254, 5:0.645735, 6:0.648645, 7:0.650881, 8:0.652386, 9:0.654163,
            10:0.655771, 20:0.663651, 30:0.666547, 40:0.668601, 50:0.670189, 60:0.671383, 70:0.671999, 80:0.672960, 90:0.673365,
            100:0.673851 }
fm_acc_loss_dict_list = {1:0.650441, 2:0.643616, 3:0.638757, 4:0.634982, 5:0.631940, 6:0.629004, 7:0.626934, 8:0.625326, 9:0.623609,
                  10:0.622356, 20:0.614875, 30:0.611119, 40:0.609767, 50:0.607636, 60:0.606768, 70:0.606124, 80:0.605916, 90:0.605070,
                  100:0.605233 }

# %%
fm_auc_dict_list = {1:0.659858, 2:0.672610, 3:0.680466, 4:0.687461, 5:0.693091, 6:0.697160, 7:0.700084, 8:0.702592, 9:0.705117,
            10:0.706930, 20:0.718192, 30:0.723148, 40:0.725976, 50:0.727855, 60:0.729234, 70:0.730219, 80:0.731061, 90:0.731763,
            100:0.732296 }
fm_auc_loss_dict_list = {1:0.650526, 2:0.643351, 3:0.639257, 4:0.635003, 5:0.631658, 6:0.628909, 7:0.626985, 8:0.625562, 9:0.623592,
                  10:0.622389, 20:0.614612, 30:0.611154, 40:0.609133, 50:0.607800, 60:0.606906, 70:0.606215, 80:0.605589, 90:0.605068,
                  100:0.604728 }

# %%
# 导入依赖
import numpy as np
# %matplotlib inline
import matplotlib # 注意这个也要import一次
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from matplotlib.pyplot import MultipleLocator
#从pyplot导入MultipleLocator类，这个类用于设置刻度间隔

# %%
# 渲染图设定
plt.rcParams['figure.figsize'] = (5.0, 4.0)
plt.rcParams['savefig.dpi'] = 300 #图片像素
plt.rcParams['figure.dpi'] = 300 #分辨率
# 默认的像素：[6.0,4.0]，分辨率为100，图片尺寸为 600&400
# 指定dpi=200，图片尺寸为 1200*800
# 指定dpi=300，图片尺寸为 1800*1200
# 设置figsize可以在不改变分辨率情况下改变比例

# %%
range_x_left, range_y_left = 0, 0.55
range_x_right, range_y_right = 100,0.74
plt.title("acc of FM and FFM")
plt.xlabel('ratio of part-of-train data and all-train data')
plt.ylabel('acc') 
plt.xlim([range_x_left, range_x_right]) 
plt.ylim([range_y_left, range_y_right]) 
plt.plot(ffm_acc_dict_list.keys(),ffm_acc_dict_list.values() ,'b*', label='FFM')
plt.plot(ffm_acc_dict_list.keys(),ffm_acc_dict_list.values() ,'b.-')
plt.plot(fm_acc_dict_list.keys(),fm_acc_dict_list.values() ,'rx', label='FM')
plt.plot(fm_acc_dict_list.keys(),fm_acc_dict_list.values() ,'r.-')
x_major_locator=MultipleLocator(10)
#把x轴的刻度间隔设置为1，并存在变量里
y_major_locator=MultipleLocator(0.02)
#把y轴的刻度间隔设置为10，并存在变量里
ax=plt.gca()
#ax为两条坐标轴的实例
ax.xaxis.set_major_locator(x_major_locator)
#把x轴的主刻度设置为1的倍数
ax.yaxis.set_major_locator(y_major_locator)
#把y轴的主刻度设置为10的倍数
plt.legend()
plt.savefig('acc_of_FM_and_FFM.png', dpi=300) #指定分辨率保存
plt.show()

# %%
range_x_left, range_y_left = 0, 0.65
range_x_right, range_y_right = 100,0.8
plt.title("auc of FM and FFM")
plt.xlabel('ratio of part-of-train data and all-train data')
plt.ylabel('auc') 
plt.xlim([range_x_left, range_x_right]) 
plt.ylim([range_y_left, range_y_right]) 
plt.plot(ffm_auc_dict_list.keys(),ffm_auc_dict_list.values() ,'b*', label='FFM')
plt.plot(ffm_auc_dict_list.keys(),ffm_auc_dict_list.values() ,'b.-')
plt.plot(fm_auc_dict_list.keys(),fm_auc_dict_list.values() ,'rx', label='FM')
plt.plot(fm_auc_dict_list.keys(),fm_auc_dict_list.values() ,'r.-')
x_major_locator=MultipleLocator(10)
ax=plt.gca()
#ax为两条坐标轴的实例
ax.xaxis.set_major_locator(x_major_locator)
#把x轴的主刻度设置为1的倍数
# ax.yaxis.set_major_locator(y_major_locator)
#把y轴的主刻度设置为10的倍数
plt.legend()
plt.savefig('auc_of_FM_and_FFM.png', dpi=300) #指定分辨率保存
plt.show()

# %%
range_x_left, range_y_left = 0, 0.54
range_x_right, range_y_right = 100,0.68
plt.title("acc Loss of FM and FFM")
plt.xlabel('ratio of part-of-train data and all-train data')
plt.ylabel('acc loss') 
plt.xlim([range_x_left, range_x_right]) 
plt.ylim([range_y_left, range_y_right]) 
plt.plot(ffm_acc_loss_dict_list.keys(),ffm_acc_loss_dict_list.values() ,'b*', label='FFM')
plt.plot(ffm_acc_loss_dict_list.keys(),ffm_acc_loss_dict_list.values() ,'b')
plt.plot(fm_acc_loss_dict_list.keys(),fm_acc_loss_dict_list.values() ,'rx', label='FM')
plt.plot(fm_acc_loss_dict_list.keys(),fm_acc_loss_dict_list.values() ,'r')
x_major_locator=MultipleLocator(10)
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
plt.legend()
plt.savefig('acc_loss_of_FM_and_FFM.png', dpi=300) #指定分辨率保存
plt.show()

# %%
range_x_left, range_y_left = 0, 0.54
range_x_right, range_y_right = 100,0.68
plt.title("auc Loss of FM and FFM")
plt.xlabel('ratio of part-of-train data and all-train data')
plt.ylabel('auc loss') 
plt.xlim([range_x_left, range_x_right]) 
plt.ylim([range_y_left, range_y_right]) 
plt.plot(ffm_auc_loss_dict_list.keys(),ffm_auc_loss_dict_list.values() ,'b*', label='FFM')
plt.plot(ffm_auc_loss_dict_list.keys(),ffm_auc_loss_dict_list.values() ,'b')
plt.plot(fm_auc_loss_dict_list.keys(),fm_auc_loss_dict_list.values() ,'rx', label='FM')
plt.plot(fm_auc_loss_dict_list.keys(),fm_auc_loss_dict_list.values() ,'r')
x_major_locator=MultipleLocator(10)
ax=plt.gca()
ax.xaxis.set_major_locator(x_major_locator)
plt.legend()
plt.savefig('auc_loss_of_FM_and_FFM.png', dpi=300) #指定分辨率保存
plt.show()
